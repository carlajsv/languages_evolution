# %%
from funciones_b import *
pd.set_option('display.max_rows', None)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\brend\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\brend\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Word counting

# %% [markdown]
# ## The 20's

# %%
lyrics_df_20 = pd.read_csv("lyrics_20_senti.csv")

# %%
lyrics_20_words = count_words(lyrics_df_20)

# %%
Total_word_20 = lyrics_20_words['Word Counts'].sum()
print("Total words 20s:",Total_word_20)
Total_unique_20 = lyrics_20_words['Unique Word Counts'].sum()
print("Unique Word Counts 20s:",Total_unique_20)
# Out:
# Total words 20s: 5263
# Unique Word Counts 20s: 2499

# %%
lyrics_20_words[lyrics_20_words['Word Counts']==lyrics_20_words['Word Counts'].max()]
# Out:
#     Unnamed: 0                                  Title       Artists  \
# 11          12  If You Knew Susie (Like I Know Susie)  Eddie Cantor
#
#                        Album_name  Duration_ms  \
# 11  The Columbia Years: 1922-1940       171506
#
#                                                Lyrics  \
# 11  if you knew susie  if you knew susie, like i k...
#
#                                             Sentiment    neg    neu    pos  \
# 11  {'neg': 0.064, 'neu': 0.665, 'pos': 0.271, 'co...  0.064  0.665  0.271
#
#     compound  Word Counts  Unique Word Counts
# 11    0.9984          342                 131

# %%
lyrics_20_words[lyrics_20_words['Word Counts']==lyrics_20_words['Word Counts'].min()]
# Out:
#     Unnamed: 0   Title       Artists Album_name  Duration_ms  \
# 13          14  Margie  Eddie Cantor    Oh Gee!       176823
#
#                                                Lyrics  \
# 13  margie my little margie, i'm always thinkin' o...
#
#                                             Sentiment  neg    neu    pos  \
# 13  {'neg': 0.0, 'neu': 0.835, 'pos': 0.165, 'comp...  0.0  0.835  0.165
#
#     compound  Word Counts  Unique Word Counts
# 13    0.8971           64                  51

# %% [markdown]
# ## The 30's

# %%
lyrics_30_senti = pd.read_csv('lyrics_30_senti.csv',index_col=0)

# %%
lyrics_30_senti.rename(columns={'lyrics':'Lyrics'},inplace=True)

# %%
lyrics_30_words = count_words(lyrics_30_senti)

# %%
lyrics_30_words.to_csv("lyrics_30_words.csv")

# %%
Total_word_30 = lyrics_30_words['Word Counts'].sum()
print("Total words 30s:",Total_word_30)
Total_unique_30 = lyrics_30_words['Unique Word Counts'].sum()
print("Unique Word Counts 30s:",Total_unique_30)
# Out:
# Total words 30s: 5702
# Unique Word Counts 30s: 2885

# %%
lyrics_30_words[lyrics_30_words['Word Counts']==lyrics_30_words['Word Counts'].max()]
# Out:
#                                               Title              Artists  \
# 18  Bei Mir Bist Du Schon (Means That You're Grand)  The Andrews Sisters
#
#     Duration_ms                                             Lyrics  \
# 18       183973  bei mir bist du schoen  of all the boys i've k...
#
#                                             Sentiment    neg    neu    pos  \
# 18  {'neg': 0.006, 'neu': 0.829, 'pos': 0.164, 'co...  0.006  0.829  0.164
#
#     compound  Word Counts  Unique Word Counts
# 18    0.9906          249                 103

# %%
lyrics_30_words[lyrics_30_words['Word Counts']==lyrics_30_words['Word Counts'].min()]
# Out:
#                  Title         Artists  Duration_ms  \
# 36  Three Little Words  Duke Ellington       183173
#
#                                                Lyrics  \
# 36  three little words    three little words oh, w...
#
#                                             Sentiment    neg    neu    pos  \
# 36  {'neg': 0.029, 'neu': 0.725, 'pos': 0.246, 'co...  0.029  0.725  0.246
#
#     compound  Word Counts  Unique Word Counts
# 36    0.9551           61                  46

# %% [markdown]
# ## The 40's

# %%
lyrics_40_senti = pd.read_csv('lyrics_40_senti.csv',index_col=0)

# %%
lyrics_40_words = count_words(lyrics_40_senti)
lyrics_40_words.to_csv("lyrics_40_words.csv")

# %%
lyrics_40_words['new_col'] = range(1, len(lyrics_40_words) + 1)

# %%
lyrics_40_words_s = lyrics_40_words[lyrics_40_words['new_col']<51]
lyrics_40_words_s
# Out:
#     Decade  Year                                              title  \
# 0     1940  1942                                    White Christmas
# 1     1940  1941                                           Stardust
# 2     1940  1949                    Rudolph, the Red-Nosed Reindeer
# 4     1940  1943                                         Paper Doll
# 5     1940  1942                                    As Time Goes By
# 6     1940  1947                                           Near You
# 7     1940  1940                             I’ll Never Smile Again
# 8     1940  1941                              Chattanooga Choo Choo
# 9     1940  1946                                 The Christmas Song
# 11    1940  1944                                 Swinging on a Star
# 14    1940  1940                          When You Wish Upon a Star
# 16    1940  1944                                 I’ll Be Seeing You
# 17    1940  1940                                            Frenesi
# ...

# %%
Total_word_40_s = lyrics_40_words_s['Word Counts'].sum()
print("Total words 40s:",Total_word_40_s)
Total_unique_40_s = lyrics_40_words_s['Unique Word Counts'].sum()
print("Unique Word Counts 40s:",Total_unique_40_s)
# Out:
# Total words 40s: 8655
# Unique Word Counts 40s: 4084

# %%
lyrics_40_words_s[lyrics_40_words_s['Word Counts']==lyrics_40_words_s['Word Counts'].max()]
# Out:
#     Decade  Year                       title           author  order  \
# 75    1940  1948  Move on Up a Little Higher  Mahalia Jackson     76
#
#                                 Title  Popularity          Artists  \
# 75  I Will Move On Up a Little Higher        17.0  Mahalia Jackson
#
#                       Album_name  Duration_ms  \
# 75  Gospels, Spirituals, & Hymns     325733.0
#
#                                                Lyrics  \
# 75  i will move on up a little higher one a-these ...
#
#                                             Sentiment    neg   neu    pos  \
# 75  {'neg': 0.021, 'neu': 0.88, 'pos': 0.099, 'com...  0.021  0.88  0.099
#
#     compound  Word Counts  Unique Word Counts  new_col
# 75     0.985          381                 133       50

# %%
lyrics_40_words_s[lyrics_40_words_s['Word Counts']==lyrics_40_words_s['Word Counts'].min()]
# Out:
#     Decade  Year               title          author  order  \
# 24    1940  1941  Take the ‘A’ Train  Duke Ellington     25
#
#                  Title  Popularity         Artists               Album_name  \
# 24  Take the "A" Train        48.0  Duke Ellington  Piano In The Background
#
#     Duration_ms                                             Lyrics  \
# 24     331800.0  take the a train you must take the "a"-train t...
#
#                                             Sentiment   neg   neu  pos  \
# 24  {'neg': 0.06, 'neu': 0.94, 'pos': 0.0, 'compou...  0.06  0.94  0.0
#
#     compound  Word Counts  Unique Word Counts  new_col
# 24   -0.4215           62                  38       19

# %% [markdown]
# ## The 50's

# %%
lyrics_50_senti = pd.read_csv('lyrics_50_senti.csv',index_col=0)

# %%
lyrics_50_words = count_words(lyrics_50_senti)
lyrics_50_words.to_csv("lyrics_50_words.csv")

# %%
lyrics_50_words['new_col'] = range(1, len(lyrics_50_words) + 1)
lyrics_50_words_s = lyrics_50_words[lyrics_50_words['new_col']<51]

Total_word_50_s = lyrics_50_words_s['Word Counts'].sum()
print("Total words 50s:",Total_word_50_s)
Total_unique_50_s = lyrics_50_words_s['Unique Word Counts'].sum()
print("Unique Word Counts 50s:",Total_unique_50_s)
# Out:
# Total words 50s: 8991
# Unique Word Counts 50s: 3364

# %%
lyrics_50_words_s[lyrics_50_words_s['Word Counts']==lyrics_50_words_s['Word Counts'].max()]
# Out:
#    Decade  year      Artists                    Title  Duration_ms  \
# 9    1950  1959  Ray Charles  What'd I Say, Pt. 1 & 2     307053.0
#
#                                               Lyrics  \
# 9  whatâ€™d i say   hey mama, don't you treat me ...
#
#                                            Sentiment   neg    neu    pos  \
# 9  {'neg': 0.05, 'neu': 0.787, 'pos': 0.163, 'com...  0.05  0.787  0.163
#
#    compound  Word Counts  Unique Word Counts  new_col
# 9    0.9918          369                  96        8

# %%
lyrics_50_words_s[lyrics_50_words_s['Word Counts']==lyrics_50_words_s['Word Counts'].min()]
# Out:
#     Decade  year    Artists                                      Title  \
# 44    1950  1957  Pat Boone  Love Letters In The Sand - Single Version
#
#     Duration_ms                                             Lyrics  \
# 44     134560.0  love letters in the sand - single version on a...
#
#                                             Sentiment    neg    neu    pos  \
# 44  {'neg': 0.116, 'neu': 0.601, 'pos': 0.282, 'co...  0.116  0.601  0.282
#
#     compound  Word Counts  Unique Word Counts  new_col
# 44    0.9737           93                  52       43

# %% [markdown]
# ## The 60's

# %%
lyrics_60_senti = pd.read_csv('lyrics_60_senti.csv',index_col=0)

# %%
lyrics_60_words = count_words(lyrics_60_senti)
lyrics_60_words.to_csv("lyrics_60_words.csv")

# %%
lyrics_60_words['new_col'] = range(1, len(lyrics_60_words) + 1)
lyrics_60_words_s = lyrics_60_words[lyrics_60_words['new_col']<51]

Total_word_60_s = lyrics_60_words_s['Word Counts'].sum()
print("Total words 60s:",Total_word_60_s)
Total_unique_60_s = lyrics_60_words_s['Unique Word Counts'].sum()
print("Unique Word Counts 60s:",Total_unique_60_s)
# Out:
# Total words 60s: 9318
# Unique Word Counts 60s: 4154

# %%
lyrics_60_words_s[lyrics_60_words_s['Word Counts']==lyrics_60_words_s['Word Counts'].max()]
# Out:
#    decade  year                 title    artists            album.name  \
# 1    1960  1965  Like a Rolling Stone  Bob Dylan  Highway 61 Revisited
#
#    duration_ms                                             Lyrics  \
# 1     369600.0  like a rolling stone  once upon a time you dre...
#
#                                            Sentiment    neg    neu   pos  \
# 1  {'neg': 0.055, 'neu': 0.814, 'pos': 0.13, 'com...  0.055  0.814  0.13
#
#    compound  Word Counts  Unique Word Counts  new_col
# 1    0.9879          403                 192        2

# %%
lyrics_60_words_s[lyrics_60_words_s['Word Counts']==lyrics_60_words_s['Word Counts'].min()]
# Out:
#     decade  year    title     artists album.name  duration_ms  \
# 49    1960  1961  At Last  Etta James   At Last!     179693.0
#
#                                                Lyrics  \
# 49  at last  at last my love has come along my lon...
#
#                                             Sentiment    neg    neu   pos  \
# 49  {'neg': 0.046, 'neu': 0.724, 'pos': 0.23, 'com...  0.046  0.724  0.23
#
#     compound  Word Counts  Unique Word Counts  new_col
# 49    0.9655           95                  58       50

# %% [markdown]
# ## The 70's

# %%
lyrics_70_senti = pd.read_csv('lyrics_70_senti.csv',index_col=0)

# %%
lyrics_70_words = count_words(lyrics_70_senti)
lyrics_70_words.to_csv("lyrics_70_words.csv")

# %%
lyrics_70_words['new_col'] = range(1, len(lyrics_70_words) + 1)
lyrics_70_words_s = lyrics_70_words[lyrics_70_words['new_col']<51]

Total_word_70_s = lyrics_70_words_s['Word Counts'].sum()
print("Total words 60s:",Total_word_70_s)
Total_unique_70_s = lyrics_70_words_s['Unique Word Counts'].sum()
print("Unique Word Counts 70s:",Total_unique_70_s)
# Out:
# Total words 60s: 13061
# Unique Word Counts 70s: 5480

# %%
lyrics_70_words_s[lyrics_70_words_s['Word Counts']==lyrics_70_words_s['Word Counts'].max()]
# Out:
#     Ranking  Decade  Year          Artists    Title  \
# 22       24    1970  1978  Village People   Y.M.C.A
#
#                                                Lyrics  \
# 22  Young man, there's no need to feel down\nI sai...
#
#                                             Sentiment    neg    neu    pos  \
# 22  {'neg': 0.036, 'neu': 0.797, 'pos': 0.167, 'co...  0.036  0.797  0.167
#
#     compound  Word Counts  Unique Word Counts  new_col
# 22     0.997          462                 126       22

# %%
lyrics_70_words_s[lyrics_70_words_s['Word Counts']==lyrics_70_words_s['Word Counts'].min()]
# Out:
#     Ranking  Decade  Year       Artists             Title  \
# 50       52    1970  1971  Isaac Hayes   Theme from Shaft
#
#                                                Lyrics  \
# 50  Who's the black private dick that's a sex mach...
#
#                                             Sentiment    neg    neu  pos  \
# 50  {'neg': 0.136, 'neu': 0.864, 'pos': 0.0, 'comp...  0.136  0.864  0.0
#
#     compound  Word Counts  Unique Word Counts  new_col
# 50   -0.8611           86                  68       50

# %% [markdown]
# ## The 80's

# %%
lyrics_80_senti = pd.read_csv('lyrics_80_senti.csv',index_col=0)

# %%
lyrics_80_words = count_words(lyrics_80_senti)
lyrics_80_words.to_csv("lyrics_80_words.csv")

# %%
lyrics_80_words['new_col'] = range(1, len(lyrics_80_words) + 1)
lyrics_80_words_s = lyrics_80_words[lyrics_80_words['new_col']<51]

Total_word_80_s = lyrics_80_words_s['Word Counts'].sum()
print("Total words 80s:",Total_word_80_s)
Total_unique_80_s = lyrics_70_words_s['Unique Word Counts'].sum()
print("Unique Word Counts 80s:",Total_unique_80_s)
# Out:
# Total words 80s: 15158
# Unique Word Counts 80s: 5480

# %%
lyrics_80_words_s[lyrics_80_words_s['Word Counts']==lyrics_80_words_s['Word Counts'].max()]
# Out:
#     Ranking  Decade  Year             Author              Song  \
# 15       15    1980  1985  U.S.A. for Africa  We Are the World
#
#                                                Lyrics  \
# 15  There comes a time\nWhen we heed a certain cal...
#
#                                             Sentiment    neg    neu    pos  \
# 15  {'neg': 0.007, 'neu': 0.746, 'pos': 0.247, 'co...  0.007  0.746  0.247
#
#     compound  Word Counts  Unique Word Counts  new_col
# 15    0.9996          709                 156       15

# %%
lyrics_80_words_s[lyrics_80_words_s['Word Counts']==lyrics_80_words_s['Word Counts'].min()]
# Out:
#     Ranking  Decade  Year        Author                     Song  \
# 12       12    1980  1980  Joy Division  Love Will Tear Us Apart
#
#                                                Lyrics  \
# 12  When routine bites hard and ambitions are low\...
#
#                                             Sentiment    neg    neu    pos  \
# 12  {'neg': 0.091, 'neu': 0.485, 'pos': 0.424, 'co...  0.091  0.485  0.424
#
#     compound  Word Counts  Unique Word Counts  new_col
# 12    0.9986          148                  88       12

# %% [markdown]
# ## The 90's

# %%
lyrics_90_senti = pd.read_csv('lyrics_90_senti.csv',index_col=0)

# %%
lyrics_90_words = count_words(lyrics_90_senti)
lyrics_90_words.to_csv("lyrics_90_words.csv")

# %%
lyrics_90_words['new_col'] = range(1, len(lyrics_90_words) + 1)
lyrics_90_words_s = lyrics_90_words[lyrics_90_words['new_col']<51]

Total_word_90_s = lyrics_90_words_s['Word Counts'].sum()
print("Total words 90s:",Total_word_90_s)
Total_unique_90_s = lyrics_90_words_s['Unique Word Counts'].sum()
print("Unique Word Counts 90s:",Total_unique_90_s)
# Out:
# Total words 90s: 17198
# Unique Word Counts 90s: 6641

# %%
lyrics_90_words_s[lyrics_90_words_s['Word Counts']==lyrics_90_words_s['Word Counts'].max()]
# Out:
#     Ranking  Decade  Year        Artists          Title  \
# 34       34    1990  1992  Sir Mix-A-Lot  Baby Got Back
#
#                                                Lyrics  \
# 34  Oh my God Becky, look at her butt\nIt is so bi...
#
#                                             Sentiment    neg    neu    pos  \
# 34  {'neg': 0.085, 'neu': 0.785, 'pos': 0.131, 'co...  0.085  0.785  0.131
#
#     compound  Word Counts  Unique Word Counts  new_col
# 34    0.9806          686                 345       34

# %%
lyrics_90_words_s[lyrics_90_words_s['Word Counts']==lyrics_90_words_s['Word Counts'].min()]
# Out:
#    Ranking  Decade  Year          Artists                   Title  \
# 1        1    1990  1992  Whitney Houston  I Will Always Love You
#
#                                               Lyrics  \
# 1  If I should stay\nI would only be in your way\...
#
#                                            Sentiment    neg    neu    pos  \
# 1  {'neg': 0.008, 'neu': 0.564, 'pos': 0.428, 'co...  0.008  0.564  0.428
#
#    compound  Word Counts  Unique Word Counts  new_col
# 1     0.998          119                  57        1

# %% [markdown]
# ## The 2000's

# %%
lyrics_2000s_senti = pd.read_csv('lyrics_2000s_senti.csv',index_col=0)

# %%
lyrics_2000s_words = count_words(lyrics_2000s_senti)
lyrics_2000s_words.to_csv("lyrics_2000s_words.csv")

# %%
lyrics_2000s_words['new_col'] = range(1, len(lyrics_2000s_words) + 1)
lyrics_2000_words_s = lyrics_2000s_words[lyrics_2000s_words['new_col']<51]

Total_word_2000_s = lyrics_2000_words_s['Word Counts'].sum()
print("Total words 2000s:",Total_word_2000_s)
Total_unique_2000_s = lyrics_2000_words_s['Unique Word Counts'].sum()
print("Unique Word Counts 2000s:",Total_unique_2000_s)
# Out:
# Total words 2000s: 20348
# Unique Word Counts 2000s: 6931

# %%
lyrics_2000_words_s[lyrics_2000_words_s['Word Counts']==lyrics_2000_words_s['Word Counts'].max()]
# Out:
#    Title  Popularity Artists               Album_name  Duration_ms  \
# 38  Stan          84  Eminem  The Marshall Mathers LP       404106
#
#                                                Lyrics  \
# 38  stan   my tea's gone cold, i'm wondering why i...
#
#                                             Sentiment    neg    neu    pos  \
# 38  {'neg': 0.137, 'neu': 0.727, 'pos': 0.136, 'co...  0.137  0.727  0.136
#
#     compound  Word Counts  Unique Word Counts  new_col
# 38   -0.8514         1327                 441       32

# %%
lyrics_2000_words_s[lyrics_2000_words_s['Word Counts']==lyrics_2000_words_s['Word Counts'].min()]
# Out:
#            Title  Popularity        Artists         Album_name  Duration_ms  \
# 51  Use Somebody          77  Kings of Leon  Only By The Night       230760
#
#                                                Lyrics  \
# 51  use somebody  i've been roamin' around, always...
#
#                                             Sentiment    neg    neu    pos  \
# 51  {'neg': 0.024, 'neu': 0.732, 'pos': 0.244, 'co...  0.024  0.732  0.244
#
#     compound  Word Counts  Unique Word Counts  new_col
# 51    0.9891          160                  59       44

# %% [markdown]
# ## The 2010's

# %%
lyrics_2010_senti = pd.read_csv('lyrics_2010_senti.csv',index_col=0)

# %%
lyrics_2010_words = count_words(lyrics_2010_senti)
lyrics_2010_words.to_csv("lyrics_2010_words.csv")

# %%
lyrics_2010_words['new_col'] = range(1, len(lyrics_2010_words) + 1)
lyrics_2010_words_s = lyrics_2010_words[lyrics_2010_words['new_col']<51]

Total_word_2010_s = lyrics_2010_words_s['Word Counts'].sum()
print("Total words 2010s:",Total_word_2010_s)
Total_unique_2010_s = lyrics_2010_words_s['Unique Word Counts'].sum()
print("Unique Word Counts 2010s:",Total_unique_2010_s)
# Out:
# Total words 2010s: 20718
# Unique Word Counts 2010s: 7049

# %%
lyrics_2010_words_s[lyrics_2010_words_s['Word Counts']==lyrics_2010_words_s['Word Counts'].max()]
# Out:
#    Index  Decade  Year                                      Artist  \
# 7      8    2010  2013  Robin Thicke with T.I. & Pharrell Williams
#
#            Title                                             Lyrics  \
# 7  Blurred Lines  Everybody get up\nEverybody get up (hey, hey, ...
#
#                                            Sentiment    neg   neu   pos  \
# 7  {'neg': 0.101, 'neu': 0.74, 'pos': 0.16, 'comp...  0.101  0.74  0.16
#
#    compound  Word Counts  Unique Word Counts  new_col
# 7    0.9852          759                 265        8

# %%
lyrics_2010_words_s[lyrics_2010_words_s['Word Counts']==lyrics_2010_words_s['Word Counts'].min()]
# Out:
#    Index  Decade  Year             Artist                         Title  \
# 4      5    2010  2011  Gotye with Kimbra  Somebody That I Used to Know
#
#                                            Lyrics  \
# 4  Somebody That I Used to Know Gotye with Kimbra
#
#                                            Sentiment  neg  neu  pos  compound  \
# 4  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.0  1.0  0.0       0.0
#
#    Word Counts  Unique Word Counts  new_col
# 4            9                   9        5

# %% [markdown]
# ## General

# %%
decade = (1920,1930,1940,1950,1960,1970,1980,1990,2000,2010)
total_word = (Total_word_20,Total_word_30,Total_word_40,Total_word_50,Total_word_60,Total_word_70,Total_word_80,Total_word_90,Total_word_2000,Total_word_2010)
total_unique = (Total_unique_20,Total_unique_30,Total_unique_40,Total_unique_50,Total_unique_60,Total_unique_70,Total_unique_80,Total_unique_90,Total_unique_2000,Total_unique_2010)

# %%
dic = {'Decade':decade,
       'Total_words':total_word,
       'Total_unique_words':total_unique
}

# %%
df = pd.DataFrame(dic)
df
# Out:
#    Decade  Total_words  Total_unique_words
# 0    1920         5263                2499
# 1    1930         5702                2885
# 2    1940         9753                4686
# 3    1950        11144                4370
# 4    1960        10545                4697
# 5    1970        23114                9605
# 6    1980        28852               10814
# 7    1990        34106               12777
# 8    2000        34300               11378
# 9    2010        32521               11066

# %%
df.to_csv("df_total_words.csv")

# %%
# 50 first rows
decade = (1920,1930,1940,1950,1960,1970,1980,1990,2000,2010)
total_word = (Total_word_20,Total_word_30,Total_word_40_s,Total_word_50_s,Total_word_60_s,Total_word_70_s,Total_word_80_s,Total_word_90_s,Total_word_2000_s,Total_word_2010_s)
total_unique = (Total_unique_20,Total_unique_30,Total_unique_40_s,Total_unique_50_s,Total_unique_60_s,Total_unique_70_s,Total_unique_80_s,Total_unique_90_s,Total_unique_2000_s,Total_unique_2010_s)

dic_50 = = {'Decade':decade,
       'Total_words':total_word,
       'Total_unique_words':total_unique
}

df_50 = pd.DataFrame(dic_50)
df_50
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [312], in <cell line: 3>()
#       1 # 50 first rows
#       2 decade = (1920,1930,1940,1950,1960,1970,1980,1990,2000,2010)
# ----> 3 total_word = (Total_word_20,Total_word_30,Total_word_40_s,Total_word_50_s,Total_word_60_s,Total_word_70_s,Total_word_80_s,Total_word_90_s,Total_word_2000_s,Total_word_2010_s)
#       4 total_unique = (Total_unique_20,Total_unique_30,Total_unique_40_s,Total_unique_50_s,Total_unique_60_s,Total_unique_70_s,Total_unique_80_s,Total_unique_90_s,Total_unique_2000_s,Total_unique_2010_s)
#
# NameError: name 'Total_word_50_s' is not defined
