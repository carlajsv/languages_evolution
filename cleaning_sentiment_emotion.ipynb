# %% [markdown]
# # Libraries

# %%
from funciones_b import *
pd.set_option('display.max_rows', None)

# %% [markdown]
# # The 20's

# %% [markdown]
# ## Cleaning

# %%
lyrics_df_20 = pd.read_excel('lyrics_1920.xlsx')

# %%
lyrics_df_20.index += 1

# %%
lyrics_df_20 = lyrics_df_20.rename(columns={"name": "Title", 
                                "popularity": "Popularity",
                                "artists":"Artists",
                                "album.name":"Album_name",
                                "duration_ms":"Duration_ms",
                                "lyrics":"Lyrics",
                               })

# %%
lyrics_df_20.to_csv("lyrics_df_20_clean.csv")

# %% [markdown]
# ## Sentiment analysis and plotting

# %%
lyrics_20_senti = append_scores(lyrics_df_20, 'Lyrics')

# %%
lyrics_20_senti.to_csv("lyrics_20_senti.csv")

# %%
plt.hist(lyrics_20_senti['pos'][lyrics_20_senti['pos']>0],bins=10);
plt.hist(lyrics_20_senti['neg'][lyrics_20_senti['neg']>0],bins=10);

# %%
sns.set_style('whitegrid')
sns.kdeplot(np.array(lyrics_20_senti['pos'][lyrics_20_senti['pos']>0]), bw=0.25, fill=True);
sns.kdeplot(np.array(lyrics_20_senti['neg'][lyrics_20_senti['neg']>0]), bw=0.25, fill=True);
# Out:
# C:\Users\brend\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\brend\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Emotional analysis

# %%
lyrics_20_emo = append_emo_scores(lyrics_20_senti,'Lyrics')

# %%
lyrics_20_emo.to_csv("lyrics_20_emo.csv")

# %% [markdown]
# # The 30's

# %% [markdown]
# ## Cleaning

# %%
lyrics_df_30 = pd.read_excel('lyrics_1930.xlsx')

# %%
len(lyrics_df_30)
# Out:
# 41

# %%
lyrics_df_30 = lyrics_df_30.rename(columns={"name": "Title", 
                                
                                "artists":"Artists",
                                
                                "duration_ms":"Duration_ms",
                                "lyrics":"Lyrics",
                               })

# %%
lyrics_df_30.index += 1

# %%
lyrics_df_30.to_csv("lyrics_df_30_clean.csv")

# %% [markdown]
# ## Sentiment analysis and plotting

# %%
lyrics_30_senti = append_scores(lyrics_df_30, 'Lyrics')
lyrics_30_senti.head(1)
# Out:
#               Title       Artists  Duration_ms  \
# 1  Over The Rainbow  Judy Garland       165240
#
#                                               Lyrics  \
# 1  over the rainbow  somewhere over the rainbow w...
#
#                                            Sentiment    neg    neu    pos  \
# 1  {'neg': 0.051, 'neu': 0.806, 'pos': 0.143, 'co...  0.051  0.806  0.143
#
#    compound
# 1    0.8633

# %%
lyrics_30_senti.to_csv("lyrics_30_senti.csv")

# %%
plt.hist(lyrics_30_senti['pos'][lyrics_30_senti['pos']>0],bins=10);
plt.hist(lyrics_30_senti['neg'][lyrics_30_senti['neg']>0],bins=10);

# %%
sns.set_style('whitegrid')
sns.kdeplot(np.array(lyrics_30_senti['pos'][lyrics_30_senti['pos']>0]), bw=0.25, fill=True)
sns.kdeplot(np.array(lyrics_30_senti['neg'][lyrics_30_senti['neg']>0]), bw=0.25, fill=True)
# Out:
# C:\Users\brend\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\brend\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Emotional analysis

# %%
lyrics_30_senti = pd.read_csv("lyrics_30_senti.csv")
lyrics_30_senti.head(1)
# Out:
#    Unnamed: 0             Title       Artists  Duration_ms  \
# 0           1  Over The Rainbow  Judy Garland       165240
#
#                                               Lyrics  \
# 0  over the rainbow  somewhere over the rainbow w...
#
#                                            Sentiment    neg    neu    pos  \
# 0  {'neg': 0.051, 'neu': 0.806, 'pos': 0.143, 'co...  0.051  0.806  0.143
#
#    compound
# 0    0.8633

# %%
lyrics_30_emo = append_emo_scores(lyrics_30_senti,'Lyrics')

# %%
lyrics_30_emo.to_csv("lyrics_30_emo.csv")

# %% [markdown]
# # The 40's

# %% [markdown]
# ## Cleaning

# %%
lyrics_df_40 = pd.read_csv('df_40s.csv')
len(lyrics_df_40)
# Out:
# 90

# %%
lyrics_df_40.rename(columns={
    'decade':'Decade',
    'year':'Year',
    'name':'Title',
    'popularity':'Popularity',
    'artists':'Artists',
    'album.name':'Album_name',
    'duration_ms':'Duration_ms',
    'lyrics':'Lyrics'
},inplace=True)

# %%
# Remove rows with NaN values or where the text is not a song
lyrics_df_40 = lyrics_df_40.drop([56,60,67])
len(lyrics_df_40)

# %%
# Remove rows with NaN values or where the text is not a song
lyrics_df_40 = lyrics_df_40.drop([3,10,12,13,15,20,25,27,31,32,34,37,38,39,40,41,42,43,49,59,60,67,68,71,72,73,76,79,81,82,83,84])
len(lyrics_df_40)
# Out:
# 58

# %%
lyrics_df_40.to_csv("lyrics_df_40_clean.csv")

# %% [markdown]
# ## Sentiment analysis and plotting

# %%
lyrics_40_senti = append_scores(lyrics_df_40, 'Lyrics')
lyrics_40_senti.head(1)
# Out:
#    Decade  Year            title       author  order                      id  \
# 0    1940  1942  White Christmas  Bing Crosby      1  4so0Wek9Ig1p6CRCHuINwW
#
#              Title  Popularity      Artists  \
# 0  White Christmas        49.0  Bing Crosby
#
#                                          Album_name  ...  \
# 0  Holiday Inn (Original Motion Picture Soundtrack)  ...
#
#                                     uri explicit  album.release_date  \
# 0  spotify:track:4so0Wek9Ig1p6CRCHuINwW      0.0          1942-01-01
#
#   Duration_ms                                             Lyrics  \
# 0    177480.0  white christmas i'm dreaming of a white christ...
#
#                                            Sentiment  neg    neu    pos  \
# 0  {'neg': 0.0, 'neu': 0.854, 'pos': 0.146, 'comp...  0.0  0.854  0.146
#
#    compound
# 0    0.9501
#
# [1 rows x 21 columns]

# %%
lyrics_40_senti = lyrics_40_senti.drop(columns=['external_urls.spotify','uri','explicit','album.release_date','id'])

# %%
lyrics_40_senti = lyrics_40_senti.rename(columns={"name": "Title", 
                                "popularity": "Popularity",
                                "artists":"Artists",
                                "album.name":"Album_name",
                                "duration_ms":"Duration_ms",
                                "lyrics":"Lyrics",
                               })

# %%
lyrics_40_senti.to_csv("lyrics_40_senti.csv")

# %%
plt.hist(lyrics_40_senti['pos'][lyrics_40_senti['pos']>0],bins=10);
plt.hist(lyrics_40_senti['neg'][lyrics_40_senti['neg']>0],bins=10);

# %%
sns.set_style('whitegrid')
sns.kdeplot(np.array(lyrics_40_senti['pos'][lyrics_40_senti['pos']>0]), bw=0.25, fill=True);
sns.kdeplot(np.array(lyrics_40_senti['neg'][lyrics_40_senti['neg']>0]), bw=0.25, fill=True);
# Out:
# C:\Users\brend\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\brend\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Emotional analysis

# %%
lyrics_40_emo = append_emo_scores(lyrics_40_senti,'Lyrics')
lyrics_40_emo.head(1)
# Out:
#    Decade  Year            title       author  order            Title  \
# 0    1940  1942  White Christmas  Bing Crosby      1  White Christmas
#
#    Popularity      Artists                                        Album_name  \
# 0        49.0  Bing Crosby  Holiday Inn (Original Motion Picture Soundtrack)
#
#    Duration_ms  ... anticipation  joy  positive  trust  fear  negative  \
# 0     177480.0  ...          7.0  9.0       9.0    7.0   NaN       NaN
#
#   sadness  anger  disgust  surprise
# 0     NaN    NaN      NaN       NaN
#
# [1 rows x 27 columns]

# %%
lyrics_40_emo.to_csv("lyrics_40_emo.csv")

# %% [markdown]
# # The 50's

# %% [markdown]
# ## Cleaning

# %%
lyrics_df_50 = pd.read_excel('lyrics_1950.xlsx')
len(lyrics_df_50)
# Out:
# 66

# %%
lyrics_df_50.index += 1

# %%
lyrics_df_50.drop([8],axis=0,inplace=True)

# %%
lyrics_df_50.to_csv("lyrics_df_50_clean.csv")

# %% [markdown]
# ## Sentiment analysis and plotting

# %%
lyrics_50_senti = append_scores(lyrics_df_50, 'lyrics')
lyrics_50_senti.head(1)
# Out:
#    decade  year      author                                 name  duration_ms  \
# 1    1950  1954  Bill Haley  (We're Gonna) Rock Around The Clock     129893.0
#
#                                               lyrics  \
# 1   rock around the clock one, two, tree o'clock,...
#
#                                            Sentiment   neg  neu   pos  \
# 1  {'neg': 0.03, 'neu': 0.9, 'pos': 0.07, 'compou...  0.03  0.9  0.07
#
#    compound
# 1     0.872

# %%
lyrics_50_senti = lyrics_50_senti.rename(columns={"name": "Title", 
                                
                                "author":"Artists",
                                "decade":"Decade",
                                "duration_ms":"Duration_ms",
                                "lyrics":"Lyrics",
                               })

# %%
lyrics_50_senti.to_csv("lyrics_50_senti.csv")

# %%
plt.hist(lyrics_50_senti['pos'][lyrics_50_senti['pos']>0],bins=10);
plt.hist(lyrics_50_senti['neg'][lyrics_50_senti['neg']>0],bins=10);

# %%
sns.set_style('whitegrid')
sns.kdeplot(np.array(lyrics_50_senti['pos'][lyrics_50_senti['pos']>0]), bw=0.25, fill=True);
sns.kdeplot(np.array(lyrics_50_senti['neg'][lyrics_50_senti['neg']>0]), bw=0.25, fill=True);
# Out:
# C:\Users\brend\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\brend\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Emotional analysis

# %%
lyrics_50_emo = append_emo_scores(lyrics_50_senti,'Lyrics')
lyrics_50_emo.head(1)
# Out:
#    Decade  year     Artists                                Title  Duration_ms  \
# 1    1950  1954  Bill Haley  (We're Gonna) Rock Around The Clock     129893.0
#
#                                               Lyrics  \
# 1   rock around the clock one, two, tree o'clock,...
#
#                                            Sentiment   neg  neu   pos  ...  \
# 1  {'neg': 0.03, 'neu': 0.9, 'pos': 0.07, 'compou...  0.03  0.9  0.07  ...
#
#    positive anticipation  anger  disgust  joy  surprise  trust  negative  \
# 1      41.0         21.0    3.0      3.0  4.0       3.0    2.0       2.0
#
#    fear  sadness
# 1   1.0      NaN
#
# [1 rows x 22 columns]

# %%
lyrics_50_emo.to_csv("lyrics_50_emo.csv")

# %% [markdown]
# # The 60's

# %% [markdown]
# ## Cleaning

# %%
lyrics_df_60 = pd.read_excel('lyrics_1960.xlsx')
len(lyrics_df_60)
# Out:
# 56

# %%
lyrics_df_60 = lyrics_df_60.rename(columns={"lyrics":"Lyrics"})

# %%
lyrics_df_60.to_csv("lyrics_df_60_clean.csv")

# %% [markdown]
# ## Sentiment analysis and plotting

# %%
lyrics_60_senti = append_scores(lyrics_df_60, 'Lyrics')
lyrics_60_senti.head(1)
# Out:
#    decade  year    title          artists  \
# 0    1960  1967  Respect  Aretha Franklin
#
#                                album.name  duration_ms  \
# 0  I Never Loved a Man the Way I Love You     147600.0
#
#                                               Lyrics  \
# 0  respect    what you want, baby, i got it what ...
#
#                                            Sentiment    neg    neu    pos  \
# 0  {'neg': 0.053, 'neu': 0.796, 'pos': 0.151, 'co...  0.053  0.796  0.151
#
#    compound
# 0    0.9589

# %%
lyrics_60_senti.to_csv("lyrics_60_senti.csv")

# %%
plt.hist(lyrics_60_senti['pos'][lyrics_60_senti['pos']>0],bins=10);
plt.hist(lyrics_60_senti['neg'][lyrics_60_senti['neg']>0],bins=10);

# %%
sns.set_style('whitegrid')
sns.kdeplot(np.array(lyrics_60_senti['pos'][lyrics_60_senti['pos']>0]), bw=0.25, fill=True);
sns.kdeplot(np.array(lyrics_60_senti['neg'][lyrics_60_senti['neg']>0]), bw=0.25, fill=True);
# Out:
# C:\Users\brend\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\brend\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Emotional analysis

# %%
lyrics_60_emo = append_emo_scores(lyrics_60_senti,'Lyrics')
lyrics_60_emo.head(1)
# Out:
#    decade  year    title          artists  \
# 0    1960  1967  Respect  Aretha Franklin
#
#                                album.name  duration_ms  \
# 0  I Never Loved a Man the Way I Love You     147600.0
#
#                                               Lyrics  \
# 0  respect    what you want, baby, i got it what ...
#
#                                            Sentiment    neg    neu  ...  \
# 0  {'neg': 0.053, 'neu': 0.796, 'pos': 0.151, 'co...  0.053  0.796  ...
#
#    anticipation   joy positive  trust  negative  fear  sadness  anger  \
# 0           9.0  13.0     15.0    8.0       5.0   1.0      1.0    3.0
#
#    surprise  disgust
# 0       3.0      NaN
#
# [1 rows x 23 columns]

# %%
lyrics_60_emo.to_csv("lyrics_60_emo.csv")

# %% [markdown]
# # The 70's

# %% [markdown]
# ## Cleaning

# %%
lyrics_df_70 = pd.read_excel('letras_1970.xlsx')
len(lyrics_df_70)
# Out:
# 86

# %%
lyrics_df_70.index += 1

# %%
lyrics_df_70.head(1)
# Out:
#    Ranking  Decade  Year Artists              Title  \
# 1        1    1970  1975  Queen   Bohemian Rhapsody
#
#                                               Lyrics
# 1  Is this the real life?\nIs this just fantasy?\...

# %%
lyrics_df_70.to_csv("lyrics_df_70_clean.csv")

# %% [markdown]
# ## Sentiment analysis and plotting

# %%
lyrics_70_senti = append_scores(lyrics_df_70, 'Lyrics')
lyrics_70_senti.head(2)
# Out:
#    Ranking  Decade  Year       Artists              Title  \
# 1        1    1970  1975        Queen   Bohemian Rhapsody
# 2        2    1970  1971  John Lennon             Imagine
#
#                                               Lyrics  \
# 1  Is this the real life?\nIs this just fantasy?\...
# 2  Imagine there's no heaven\nIt's easy if you tr...
#
#                                            Sentiment    neg    neu    pos  \
# 1  {'neg': 0.175, 'neu': 0.75, 'pos': 0.075, 'com...  0.175  0.750  0.075
# 2  {'neg': 0.121, 'neu': 0.708, 'pos': 0.171, 'co...  0.121  0.708  0.171
#
#    compound
# 1   -0.9881
# 2    0.8359

# %%
lyrics_70_senti.to_csv("lyrics_70_senti.csv")

# %%
plt.hist(lyrics_70_senti['pos'][lyrics_70_senti['pos']>0],bins=10);
plt.hist(lyrics_70_senti['neg'][lyrics_70_senti['neg']>0],bins=10);

# %%
sns.set_style('whitegrid')
sns.kdeplot(np.array(lyrics_70_senti['pos'][lyrics_70_senti['pos']>0]), bw=0.25, fill=True);
sns.kdeplot(np.array(lyrics_70_senti['neg'][lyrics_70_senti['neg']>0]), bw=0.25, fill=True);
# Out:
# C:\Users\brend\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\brend\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Emotional analysis

# %%
lyrics_70_emo = append_emo_scores(lyrics_70_senti,'Lyrics')
lyrics_70_emo
# Out:
#     Ranking  Decade  Year                              Artists  \
# 1         1    1970  1975                               Queen
# 2         2    1970  1971                         John Lennon
# 3         3    1970  1970                   Simon & Garfunkel
# 4         4    1970  1976                              Eagles
# 5         5    1970  1977                            Bee Gees
# 6         6    1970  1971                        Led Zeppelin
# 7         8    1970  1970                         The Beatles
# 8        10    1970  1976                                Abba
# 9        11    1970  1975                   Bruce Springsteen
# 10       12    1970  1978                       Gloria Gaynor
# 11       13    1970  1971                         Marvin Gaye
# 12       14    1970  1972                       Stevie Wonder
# 13       15    1970  1979                          Pink Floyd
# 14       16    1970  1971                         Rod Stewart
# ...

# %%
lyrics_70_emo.to_csv('emotions_70.txt',index=None)

# %%
lyrics_70_emo.to_csv("lyrics_70_emo.csv")

# %%
lyrics_70_emo.to_excel("prueba79.xlsx")

# %% [markdown]
# ## The 80's

# %% [markdown]
# ### Cleaning

# %%
lyrics_df_80 = pd.read_excel('letras_1980.xlsx')
len(lyrics_df_80)
# Out:
# 96

# %%
lyrics_df_80.head(3)
# Out:
#    Ranking  Decade  Year           Author                   Song  \
# 0        1    1980  1982  Michael Jackson            Billie Jean
# 1        2    1980  1983       The Police  Every Breath You Take
# 2        3    1980  1987    Guns N’ Roses    Sweet Child O’ Mine
#
#                                               Lyrics
# 0  She was more like a beauty queen from a movie ...
# 1  Every breath you take\nAnd every move you make...
# 2  She's got a smile that it seems to me\nReminds...

# %%
lyrics_df_80.index += 1

# %%
lyrics_df_80.to_csv("lyrics_df_80_clean.csv")

# %% [markdown]
# ### Sentiment analysis and plotting

# %%
lyrics_80_senti = append_scores(lyrics_df_80, 'Lyrics')
lyrics_80_senti.head(1)
# Out:
#    Ranking  Decade  Year           Author         Song  \
# 1        1    1980  1982  Michael Jackson  Billie Jean
#
#                                               Lyrics  \
# 1  She was more like a beauty queen from a movie ...
#
#                                            Sentiment    neg   neu    pos  \
# 1  {'neg': 0.086, 'neu': 0.82, 'pos': 0.094, 'com...  0.086  0.82  0.094
#
#    compound
# 1    0.5178

# %%
lyrics_80_senti.to_csv("lyrics_80_senti.csv")

# %%
plt.hist(lyrics_80_senti['pos'][lyrics_80_senti['pos']>0],bins=10);
plt.hist(lyrics_80_senti['neg'][lyrics_80_senti['neg']>0],bins=10);

# %%
sns.set_style('whitegrid')
sns.kdeplot(np.array(lyrics_80_senti['pos'][lyrics_80_senti['pos']>0]), bw=0.25, fill=True);
sns.kdeplot(np.array(lyrics_80_senti['neg'][lyrics_80_senti['neg']>0]), bw=0.25, fill=True);
# Out:
# C:\Users\brend\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\brend\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Emotional analysis

# %%
lyrics_80_senti = pd.read_csv("lyrics_80_senti.csv")
lyrics_80_senti.head(1)
# Out:
#    Unnamed: 0  Ranking  Decade  Year           Author         Song  \
# 0           1        1    1980  1982  Michael Jackson  Billie Jean
#
#                                               Lyrics  \
# 0  She was more like a beauty queen from a movie ...
#
#                                            Sentiment    neg   neu    pos  \
# 0  {'neg': 0.086, 'neu': 0.82, 'pos': 0.094, 'com...  0.086  0.82  0.094
#
#    compound
# 0    0.5178

# %%
lyrics_80_emo = append_emo_scores(lyrics_80_senti,'Lyrics')

# %%
lyrics_80_emo.to_csv("lyrics_80_emo.csv")

# %%
lyrics_80_emo.to_excel("prueba88.xlsx")

# %% [markdown]
# ## The 90's

# %% [markdown]
# ### Cleaning

# %%
lyrics_df_90 = pd.read_excel('letras_1990.xlsx')
len(lyrics_df_90)
# Out:
# 99

# %%
lyrics_df_90.index += 1

# %%
lyrics_df_90 = lyrics_df_90.rename(columns={"Song": "Title", 
                                                  "Author":"Artists"})

# %%
lyrics_df_90.to_csv("lyrics_df_90_clean.csv")

# %% [markdown]
# ### Sentiment analysis and plotting

# %%
lyrics_90_senti = append_scores(lyrics_df_90, 'Lyrics')
lyrics_90_senti.head(2)
# Out:
#    Ranking  Decade  Year          Artists                    Title  \
# 1        1    1990  1992  Whitney Houston   I Will Always Love You
# 2        2    1990  1991          Nirvana  Smells Like Teen Spirit
#
#                                               Lyrics  \
# 1  If I should stay\nI would only be in your way\...
# 2  Load up on guns, bring your friends\nIt's fun ...
#
#                                            Sentiment    neg    neu    pos  \
# 1  {'neg': 0.008, 'neu': 0.564, 'pos': 0.428, 'co...  0.008  0.564  0.428
# 2  {'neg': 0.19, 'neu': 0.649, 'pos': 0.161, 'com...  0.190  0.649  0.161
#
#    compound
# 1     0.998
# 2    -0.534

# %%
lyrics_90_senti.to_csv("lyrics_90_senti.csv")

# %%
plt.hist(lyrics_90_senti['pos'][lyrics_90_senti['pos']>0],bins=10);
plt.hist(lyrics_90_senti['neg'][lyrics_90_senti['neg']>0],bins=10);

# %%
sns.set_style('whitegrid')
sns.kdeplot(np.array(lyrics_90_senti['pos'][lyrics_90_senti['pos']>0]), bw=0.25, fill=True)
sns.kdeplot(np.array(lyrics_90_senti['neg'][lyrics_90_senti['neg']>0]), bw=0.25, fill=True)
# Out:
# C:\Users\brend\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\brend\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### Emotional analysis

# %%
lyrics_90_emo = append_emo_scores(lyrics_90_senti,'Lyrics')

# %%
lyrics_90_emo.head(1)
# Out:
#    Ranking  Decade  Year          Artists                   Title  \
# 1        1    1990  1992  Whitney Houston  I Will Always Love You
#
#                                               Lyrics  \
# 1  If I should stay\nI would only be in your way\...
#
#                                            Sentiment    neg    neu    pos  \
# 1  {'neg': 0.008, 'neu': 0.564, 'pos': 0.428, 'co...  0.008  0.564  0.428
#
#    ...   joy positive  negative  sadness  anticipation  surprise  trust  \
# 1  ...  12.0     12.0       1.0      1.0           3.0       2.0    3.0
#
#    anger  disgust  fear
# 1    NaN      NaN   NaN
#
# [1 rows x 22 columns]

# %%
lyrics_90_emo.to_csv("lyrics_90_emo.csv")

# %%
lyrics_90_emo.to_excel("prueba99.xlsx")

# %% [markdown]
# ## The 2000's

# %% [markdown]
# ### Cleaning

# %%
lyrics_df_2000s = pd.read_csv('lyrics_df_2000s.csv')
len(lyrics_df_2000s)
# Out:
# 90

# %%
# Remove rows with None value that is a string
lyrics_df_2000s[['lyrics']] = lyrics_df_2000s[['lyrics']].replace('None',np.nan,regex=True)
lyrics_df_2000s = lyrics_df_2000s.dropna()

# %%
# Removing rows where the text is not a song
lyrics_df_2000s = lyrics_df_2000s.drop([2, 3, 5, 8, 20, 24, 48, 71])
len(lyrics_df_2000s)
# Out:
# 80

# %%
# Removing columns
lyrics_df_2000s = lyrics_df_2000s.drop(columns=['external_urls.spotify','uri','explicit','album.release_date','id'])

# %%
lyrics_df_2000s = lyrics_df_2000s.rename(columns={"name": "Title", 
                                "popularity": "Popularity",
                                "artists":"Artists",
                                "album.name":"Album_name",
                                "duration_ms":"Duration_ms",
                                "lyrics":"Lyrics",
                               })

# %%
lyrics_df_2000s.index += 1

# %%
lyrics_df_2000s.to_csv("lyrics_df_2000s_clean.csv")

# %% [markdown]
# ### Sentiment analysis and plotting

# %%
lyrics_2000s_senti = append_scores(lyrics_df_2000s, 'Lyrics')
lyrics_2000s_senti.head(2)
# Out:
#              Title  Popularity          Artists  \
# 1          Hey Ya!          81          Outkast
# 2  I Gotta Feeling          75  Black Eyed Peas
#
#                            Album_name  Duration_ms  \
# 1         Speakerboxxx/The Love Below       235213
# 2  THE E.N.D. (THE ENERGY NEVER DIES)       289133
#
#                                               Lyrics  \
# 1  hey ya!  one, two, three, uh!   my baby don't ...
# 2  i gotta feeling  i got a feeling that tonight'...
#
#                                            Sentiment    neg    neu    pos  \
# 1  {'neg': 0.085, 'neu': 0.804, 'pos': 0.111, 'co...  0.085  0.804  0.111
# 2  {'neg': 0.008, 'neu': 0.78, 'pos': 0.211, 'com...  0.008  0.780  0.211
#
#    compound
# 1    0.9590
# 2    0.9987

# %%
lyrics_2000s_senti.to_csv("lyrics_2000s_senti.csv")

# %%
plt.hist(lyrics_2000s_senti['pos'][lyrics_2000s_senti['pos']>0],bins=10);
plt.hist(lyrics_2000s_senti['neg'][lyrics_2000s_senti['neg']>0],bins=10);

# %%
sns.set_style('whitegrid')
sns.kdeplot(np.array(lyrics_2000s_senti['pos'][lyrics_2000s_senti['pos']>0]), bw=0.25, fill=True)
sns.kdeplot(np.array(lyrics_2000s_senti['neg'][lyrics_2000s_senti['neg']>0]), bw=0.25, fill=True)
# Out:
# C:\Users\brend\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\brend\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### Emotional analysis

# %%
lyrics_2000s_senti = pd.read_csv("lyrics_2000s_senti.csv")
lyrics_2000s_senti.head(1)
# Out:
#    Unnamed: 0    Title  Popularity  Artists                   Album_name  \
# 0           1  Hey Ya!          81  Outkast  Speakerboxxx/The Love Below
#
#    Duration_ms                                             Lyrics  \
# 0       235213  hey ya!  one, two, three, uh!   my baby don't ...
#
#                                            Sentiment    neg    neu    pos  \
# 0  {'neg': 0.085, 'neu': 0.804, 'pos': 0.111, 'co...  0.085  0.804  0.111
#
#    compound
# 0     0.959

# %%
lyrics_2000s_emo = append_emo_scores(lyrics_2000s_senti,'Lyrics')

# %%
lyrics_2000s_emo.to_csv("lyrics_2000s_emo.csv")

# %% [markdown]
# ## The 2010's

# %% [markdown]
# ### Cleaning

# %%
lyrics_df_2010 = pd.read_excel('letras_2010.xlsx')
len(lyrics_df_2010)
# Out:
# 80

# %%
lyrics_df_2010 = lyrics_df_2010.rename(columns={"Song": "Title", 
                                                  "Author":"Artists"})

# %%
lyrics_df_2010.to_csv("lyrics_df_2010_clean.csv")

# %% [markdown]
# ### Sentiment analysis and plotting

# %%
lyrics_2010_senti = append_scores(lyrics_df_2010, 'Lyrics')
lyrics_2010_senti.head(2)
# Out:
#    Index  Decade  Year                       Artist         Title  \
# 0      1    2010  2014  Mark Ronson with Bruno Mars  Uptown Funk!
# 1      2    2010  2017                   Ed Sheeran  Shape of You
#
#                                               Lyrics  \
# 0  This hit, that ice cold\nMichelle Pfeiffer, th...
# 1  The club isn't the best place to find a lover\...
#
#                                            Sentiment    neg    neu    pos  \
# 0  {'neg': 0.05, 'neu': 0.852, 'pos': 0.098, 'com...  0.050  0.852  0.098
# 1  {'neg': 0.021, 'neu': 0.755, 'pos': 0.224, 'co...  0.021  0.755  0.224
#
#    compound
# 0    0.9869
# 1    0.9994

# %%
lyrics_2010_senti.to_csv("lyrics_2010_senti.csv")

# %%
plt.hist(lyrics_2010_senti['pos'][lyrics_2010_senti['pos']>0],bins=10);
plt.hist(lyrics_2010_senti['neg'][lyrics_2010_senti['neg']>0],bins=10);

# %%
sns.set_style('whitegrid')
sns.kdeplot(np.array(lyrics_2010_senti['pos'][lyrics_2010_senti['pos']>0]), bw=0.25, fill=True)
sns.kdeplot(np.array(lyrics_2010_senti['neg'][lyrics_2010_senti['neg']>0]), bw=0.25, fill=True)
# Out:
# C:\Users\brend\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\brend\anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### Emotional analysis

# %%
lyrics_2010_emo = append_emo_scores(lyrics_2010_senti,'Lyrics')
# Out:
# C:\Users\brend\Documents\ironhack\proyectos\4_proyecto_eda\ipynb\pruebas\funciones_b.py:75: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_with_lyrics = pd.concat([df_with_lyrics, df_with_lyrics['Emotion'].apply(pd.Series)], axis=1)
# C:\Users\brend\Documents\ironhack\proyectos\4_proyecto_eda\ipynb\pruebas\funciones_b.py:75: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_with_lyrics = pd.concat([df_with_lyrics, df_with_lyrics['Emotion'].apply(pd.Series)], axis=1)
# C:\Users\brend\Documents\ironhack\proyectos\4_proyecto_eda\ipynb\pruebas\funciones_b.py:75: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# ...

# %%
lyrics_2010_emo.to_csv("lyrics_2010_emo.csv")

# %%
lyrics_2010_emo.to_excel("prueba10.xlsx")
